# %%
import pandas as pd

# %%
pasthair=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/PastHires.csv')

# %%
pasthair.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Years Experience    13 non-null     int64
#  1   Employed            13 non-null     object
#  2   Previous Employers  13 non-null     int64
#  3   Level of Education  13 non-null     object
#  4   Top-tier School     13 non-null     object
#  5   Interned            13 non-null     object
#  6   Hired               13 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 856.0+ bytes

# %%
pasthair.shape
# Out:
# (13, 7)

# %%
pasthair.columns
# Out:
# Index(['Years Experience', 'Employed', 'Previous Employers',
#        'Level of Education', 'Top-tier School', 'Interned', 'Hired'],
#       dtype='object')

# %%
icecream=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Ice%20Cream.csv')

# %%
icecream.shape
# Out:
# (500, 2)

# %%
icecream.head(

)
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
icecream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
icecream.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
y=icecream['Revenue']
x=icecream[['Temperature']]

# %%
#step 4=traim test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)
x_train
# Out:
#      Temperature
# 308         33.4
# 284         22.2
# 76          40.5
# 152         12.3
# 184         29.2
# ..           ...
# 228         38.2
# 399         33.6
# 316         25.2
# 50           6.4
# 352         12.8
#
# [350 rows x 1 columns]

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((350, 1), (150, 1), (350,), (150,))

# %%
# step5=linar regression y=c+mx

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#step 6= train the model for fit

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 42.444772590839705

# %%
model.coef_
# Out:
# array([21.54587147])

# %%
# so the eq is revenue =42.4+21.*temp+error

# %%
#step 7= prediction

# %%
model.predict(x_test)
y_pre=model.predict(x_test)

# %%
#step 8=accuracy

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(x_test,y_pre)
# Out:
# 23.049329015515625

# %%
# therfor the erroe is more so the data is not a
