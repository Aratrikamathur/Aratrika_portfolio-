# %%
import pandas as pd

# %%
micro=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Customer%20Purchase.csv')

# %%
micro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  50 non-null     int64
#  1   Age          50 non-null     int64
#  2   Gender       50 non-null     object
#  3   Education    50 non-null     object
#  4   Review       50 non-null     object
#  5   Purchased    50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
micro.head()
# Out:
#    Customer ID  Age  Gender Education   Review Purchased
# 0         1021   30  Female    School  Average        No
# 1         1022   68  Female        UG     Poor        No
# 2         1023   70  Female        PG     Good        No
# 3         1024   72  Female        PG     Good        No
# 4         1025   16  Female        UG  Average        No

# %%
micro.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Education', 'Review', 'Purchased'], dtype='object')

# %%
y = micro['Purchased']
X = micro[['Customer ID', 'Age', 'Gender', 'Education', 'Review']]

# %%
X.replace({'Review':{'Poor':0,'Average':1,'Good':2}},inplace=True)
X.replace({'Education':{'School':0,'UG':1,'PG':2}},inplace=True)
X.replace({'Gender':{'Male': 0,'Female':1}},inplace=True)
# Out:
# <ipython-input-9-a67e26d52802>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace({'Review':{'Poor':0,'Average':1,'Good':2}},inplace=True)
# <ipython-input-9-a67e26d52802>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace({'Education':{'School':0,'UG':1,'PG':2}},inplace=True)
# <ipython-input-9-a67e26d52802>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace({'Gender':{'Male': 0,'Female':1}},inplace=True)

# %%
X.head()
# Out:
#    Customer ID  Age  Gender  Education  Review
# 0         1021   30       1          0       1
# 1         1022   68       1          1       0
# 2         1023   70       1          2       2
# 3         1024   72       1          2       2
# 4         1025   16       1          1       1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7, 0],
#        [6, 2]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
 classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n          No       0.54      1.00      0.70         7\n         Yes       1.00      0.25      0.40         8\n\n    accuracy                           0.60        15\n   macro avg       0.77      0.62      0.55        15\nweighted avg       0.78      0.60      0.54        15\n'
